# %%
"""

Barium


"""


import pandas as pd
from IPython.display import display, Latex

Barium = { 

    "Ba-133 Peak 2:": ['663 counts', '180 counts', '843 counts', '276.400 kev', '276.2961 kev',
                '0.12', '0.001', '0.0069', '-0.104 kev', '1563.71 channel', '39'], 
    
    "Ba-133 Peak 3:": ['1755 counts', '0 counts', '1755 counts', '302.851 kev', '302.796 kev',
                '0.07', '0.001', '0.007', '-0.055 kev', '1700.76 channel', '42'], 

    "Ba-133 Peak 4:": ['4563 counts', '0 counts', '4563 counts', '356.013 kev', '356.013 kev', '0.04', 
                      '0.001', '0.006', '0.025 kev', '1976.12 channel', '68'], 

    "Ba-133 Peak 5:": ['613 counts', '0 counts', '613 counts', '383.848 kev', '383.92 kev','0.12',
                       '0.001', '0.06', '0.072 kev', '2120.21 channel', '25' ], 



}


df = pd.DataFrame(Barium, index = [r'$N_s$', r'$N_b$', r'$N_T$', 
                                    r'$E_L$', r'$E_F$', 
                                    r'$\frac{\sigma}{\sqrt{N_S}}$', 
                                    r'$\sigma_{E_L}$', 
                                    r'$\sigma_{\text{cal}}$', 
                                    r'$R$', r'$\bar{X}$', r'$\sigma_{\text{count}}$'])
# Export to LaTeX format
latex_table = df.to_latex(escape=False)  # escape=False allows LaTeX symbols

# Save to a .tex file
with open('sources.tex', 'w') as f:
    f.write(latex_table)

# Output the LaTeX table to the console
print(latex_table)
# Display LaTeX table
display(Latex(latex_table))
# Out:
# \begin{tabular}{lllll}
# \toprule
#  & Ba-133 Peak 2: & Ba-133 Peak 3: & Ba-133 Peak 4: & Ba-133 Peak 5: \\
# \midrule
# $N_s$ & 663 counts & 1755 counts & 4563 counts & 613 counts \\
# $N_b$ & 180 counts & 0 counts & 0 counts & 0 counts \\
# $N_T$ & 843 counts & 1755 counts & 4563 counts & 613 counts \\
# $E_L$ & 276.400 kev & 302.851 kev & 356.013 kev & 383.848 kev \\
# $E_F$ & 276.2961 kev & 302.796 kev & 356.013 kev & 383.92 kev \\
# $\frac{\sigma}{\sqrt{N_S}}$ & 0.12 & 0.07 & 0.04 & 0.12 \\
# $\sigma_{E_L}$ & 0.001 & 0.001 & 0.001 & 0.001 \\
# $\sigma_{\text{cal}}$ & 0.0069 & 0.007 & 0.006 & 0.06 \\
# $R$ & -0.104 kev & -0.055 kev & 0.025 kev & 0.072 kev \\
# $\bar{X}$ & 1563.71 channel & 1700.76 channel & 1976.12 channel & 2120.21 channel \\
# $\sigma_{\text{count}}$ & 39 & 42 & 68 & 25 \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lllll}
# \toprule
#  & Ba-133 Peak 2: & Ba-133 Peak 3: & Ba-133 Peak 4: & Ba-133 Peak 5: \\
# \midrule
# ...

# %%
"""

Cobalt


"""


import pandas as pd
from IPython.display import display, Latex

Cobalt = { 

    "Co-60 Peak 1:": ['1446 counts', '1173.237 kev', '1173.28 kev', 
                      '0.12', '0.004', '0.016', '0.043 kev', 
                     '6202.74 channel', '38'],
    
    "Co-60 Peak 2:": ['1184 counts', '1332.501 kev', '1332.41 kev', '0.15', 
                     '0.005', '0.02', '-0.089 kev', '7025.74 channel', '34'],



}


df = pd.DataFrame(Cobalt, index = [r'$N$',  
                                    r'$E_L$', r'$E_F$', 
                                    r'$\frac{\sigma}{\sqrt{N}}$', 
                                    r'$\sigma_{E_L}$', 
                                    r'$\sigma_{\text{cal}}$', 
                                    r'$R$', r'$\bar{X}$', r'$\sigma_{\text{count}}$' ])
# Export to LaTeX format
latex_table2 = df.to_latex(escape=False)  # escape=False allows LaTeX symbols

# Save to a .tex file
with open('sources.tex', 'w') as f:
    f.write(latex_table2)

# Output the LaTeX table to the console
print(latex_table2)
# Display LaTeX table
display(Latex(latex_table2))
# Out:
# \begin{tabular}{lll}
# \toprule
#  & Co-60 Peak 1: & Co-60 Peak 2: \\
# \midrule
# $N$ & 1446 counts & 1184 counts \\
# $E_L$ & 1173.237 kev & 1332.501 kev \\
# $E_F$ & 1173.28 kev & 1332.41 kev \\
# $\frac{\sigma}{\sqrt{N}}$ & 0.12 & 0.15 \\
# $\sigma_{E_L}$ & 0.004 & 0.005 \\
# $\sigma_{\text{cal}}$ & 0.016 & 0.02 \\
# $R$ & 0.043 kev & -0.089 kev \\
# $\bar{X}$ & 6202.74 channel & 7025.74 channel \\
# $\sigma_{\text{count}}$ & 38 & 34 \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lll}
# \toprule
#  & Co-60 Peak 1: & Co-60 Peak 2: \\
# \midrule
# $N$ & 1446 counts & 1184 counts \\
# $E_L$ & 1173.237 kev & 1332.501 kev \\
# $E_F$ & 1173.28 kev & 1332.41 kev \\
# $\frac{\sigma}{\sqrt{N}}$ & 0.12 & 0.15 \\
# $\sigma_{E_L}$ & 0.004 & 0.005 \\
# $\sigma_{\text{cal}}$ & 0.016 & 0.02 \\
# $R$ & 0.043 kev & -0.089 kev \\
# $\bar{X}$ & 6202.74 channel & 7025.74 channel \\
# $\sigma_{\text{count}}$ & 38 & 34 \\
# \bottomrule
# \end{tabular}

# %%
"""

Cesium


"""


import pandas as pd
from IPython.display import display, Latex

Cesium = { 

    "Cs-137 Peak 1:": ['2262 counts', '661.657 kev', 
                       '661.658 kev', '0.077', '0.003', '0.007', 
                        '-0.004 kev', '3556.72 channel', '48'] 
    


}


df = pd.DataFrame(Cesium, index = [r'$N$',  
                                    r'$E_L$', r'$E_F$', 
                                    r'$\frac{\sigma}{\sqrt{N}}$', 
                                    r'$\sigma_{E_L}$', 
                                    r'$\sigma_{\text{cal}}$', 
                                    r'$R$', r'$\bar{X}$', r'$\sigma_{\text{count}}$' ])
# Export to LaTeX format
latex_table3 = df.to_latex(escape=False)  # escape=False allows LaTeX symbols

# Save to a .tex file
with open('sources.tex', 'w') as f:
    f.write(latex_table3)

# Output the LaTeX table to the console
print(latex_table3)
# Display LaTeX table
display(Latex(latex_table3))
# Out:
# \begin{tabular}{ll}
# \toprule
#  & Cs-137 Peak 1: \\
# \midrule
# $N$ & 2262 counts \\
# $E_L$ & 661.657 kev \\
# $E_F$ & 661.658 kev \\
# $\frac{\sigma}{\sqrt{N}}$ & 0.077 \\
# $\sigma_{E_L}$ & 0.003 \\
# $\sigma_{\text{cal}}$ & 0.007 \\
# $R$ & -0.004 kev \\
# $\bar{X}$ & 3556.72 channel \\
# $\sigma_{\text{count}}$ & 48 \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{ll}
# \toprule
#  & Cs-137 Peak 1: \\
# \midrule
# $N$ & 2262 counts \\
# $E_L$ & 661.657 kev \\
# $E_F$ & 661.658 kev \\
# $\frac{\sigma}{\sqrt{N}}$ & 0.077 \\
# $\sigma_{E_L}$ & 0.003 \\
# $\sigma_{\text{cal}}$ & 0.007 \\
# $R$ & -0.004 kev \\
# $\bar{X}$ & 3556.72 channel \\
# $\sigma_{\text{count}}$ & 48 \\
# \bottomrule
# \end{tabular}

# %%
"""

Calibration


"""


import pandas as pd
from IPython.display import display, Latex

Calibration = { 

    "Calibration Parameters:": ['0.193356', '-26.057', 
                                r'$-4.12\times 10^{-8}$', '0.000004',
                                '0.012'],
    


}


df = pd.DataFrame(Calibration, index = [r'$a_1$', r'$b_1$', 'Cov(a,b)', 
                                        r'$\sigma_{a}$', r'$\sigma_{b}$' ])
# Export to LaTeX format
latex_table4 = df.to_latex(escape=False)  # escape=False allows LaTeX symbols

# Save to a .tex file
with open('sources.tex', 'w') as f:
    f.write(latex_table4)

# Output the LaTeX table to the console
print(latex_table4)
# Display LaTeX table
display(Latex(latex_table4))
# Out:
# \begin{tabular}{ll}
# \toprule
#  & Calibration Parameters: \\
# \midrule
# $a_1$ & 0.193356 \\
# $b_1$ & -26.057 \\
# Cov(a,b) & $-4.12\times 10^{-8}$ \\
# $\sigma_{a}$ & 0.000004 \\
# $\sigma_{b}$ & 0.012 \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{ll}
# \toprule
#  & Calibration Parameters: \\
# \midrule
# $a_1$ & 0.193356 \\
# $b_1$ & -26.057 \\
# Cov(a,b) & $-4.12\times 10^{-8}$ \\
# $\sigma_{a}$ & 0.000004 \\
# $\sigma_{b}$ & 0.012 \\
# \bottomrule
# \end{tabular}

# %%
import pandas as pd
from IPython.display import display, Latex

Eu1 = { 
    "Eu-152 Peak 1:": ['20758 counts', '19458 counts', '1300 counts', 
                        '150', '0.018', '121.782 kev', 
                         '120.37 kev', '0.001', '0.0092', '-1.412 kev', '757.292 channel'], 
    
    "Eu-152 Peak 2:": ['3478 counts', '2878 counts', '600 counts', '64', 
                      '0.056', '244.697 kev', '244.49 kev', 
                      '0.001', '0.000054', '-0.207 kev', '1399.21 channel'], 
    
    "Eu-152 Peak 3:": ['7179 counts', '6819 counts', '360 counts', 
                       '87', '0.0037', '344.279 kev', '344.36 kev',  # Missing comma here
                       '0.001', '0.006', '0.081 kev', '1915.57 channel'],  # Correct the channel
    
    "Eu-152 Peak 4:": ['842 counts', '468 counts', '374 counts', 
                      '35', '0.25', '443.965 kev', '444.106 kev', 
                      '0.003', '0.006', '0.141 kev', '2431.59 channel'],
    
    "Eu-152 Peak 5:": ['1434 counts', '840 counts', '374 counts', '43',
                      '0.16', '778.904 kev', '778.821 kev', '0.002', 
                      '0.0086', '-0.083 kev', '4162.67 channel'],
    
    "Eu-152 Peak 6:": ['1199 counts', '912 counts', '287 counts', '39', 
                       '0.16', '964.079 kev', '963.810 kev', '0.018',  # Missing comma here
                       '0.012', '-0.269 kev', '5119.4 channel'], 
    
    "Eu-152 Peak 7:": ['795 counts', '519 counts', '278 counts', '33', '0.23', 
                      '1085.869 kev', '1085.51 kev', '0.024', '0.014', 
                       '-0.359 kev', '5748.83 channel'], 
    
    "Eu-152 Peak 8:": ['963 counts', '657 counts', '307 counts', '36', '0.21', 
                       '1112.069 kev', '1111.68 kev', '0.015', '0.006', '-0.389 kev', 
                       '5884.15 channel'], 
    
    "Eu-152 Peak 9:": ['1038 counts', '1005 counts', '33 counts', '33', '0.17',
                      '1408.006 kev', '1407.35 kev', '0.003', '0.020', '-0.656 kev', 
                       '7413.28 channel'], 
}

df = pd.DataFrame(Eu1, index = [r'$N_T$', r'$N_s$', r'$N_b$', 
                                    r'$\sigma_{\text{count}}$',
                                    r'$\frac{\sigma}{\sqrt{N_S}}$', 
                                    r'$E_L$', r'$E_F$',
                                    r'$\sigma_{E_L}$', 
                                    r'$\sigma_{\text{cal}}$', 
                                    r'$R$', r'$\bar{X}$', ])
# Export to LaTeX format
latex_table5 = df.to_latex(escape=False)  # escape=False allows LaTeX symbols

# Save to a .tex file
with open('sources.tex', 'w') as f:
    f.write(latex_table5)

# Output the LaTeX table to the console
print(latex_table5)
# Display LaTeX table
display(Latex(latex_table5))
# Out:
# \begin{tabular}{llllllllll}
# \toprule
#  & Eu-152 Peak 1: & Eu-152 Peak 2: & Eu-152 Peak 3: & Eu-152 Peak 4: & Eu-152 Peak 5: & Eu-152 Peak 6: & Eu-152 Peak 7: & Eu-152 Peak 8: & Eu-152 Peak 9: \\
# \midrule
# $N_T$ & 20758 counts & 3478 counts & 7179 counts & 842 counts & 1434 counts & 1199 counts & 795 counts & 963 counts & 1038 counts \\
# $N_s$ & 19458 counts & 2878 counts & 6819 counts & 468 counts & 840 counts & 912 counts & 519 counts & 657 counts & 1005 counts \\
# $N_b$ & 1300 counts & 600 counts & 360 counts & 374 counts & 374 counts & 287 counts & 278 counts & 307 counts & 33 counts \\
# $\sigma_{\text{count}}$ & 150 & 64 & 87 & 35 & 43 & 39 & 33 & 36 & 33 \\
# $\frac{\sigma}{\sqrt{N_S}}$ & 0.018 & 0.056 & 0.0037 & 0.25 & 0.16 & 0.16 & 0.23 & 0.21 & 0.17 \\
# $E_L$ & 121.782 kev & 244.697 kev & 344.279 kev & 443.965 kev & 778.904 kev & 964.079 kev & 1085.869 kev & 1112.069 kev & 1408.006 kev \\
# ...

# %%
import pandas as pd
from IPython.display import display, Latex




Eff1 = {

    
    "Low Energy Parameters (0-500 kev)" : [r'$1.28\times 10^{-6}$', 
                                           r'$1.27\times 10^{-6}$', 
                                           '-0.0025', '0.0009', 
                                          '1.06', '0.14'], 

  

}


Eff2 = {
    
    
    "High Energy Parameters (750-1500 kev)" : [r'$1.09\times 10^{-9}$', 
                                               r'$.43\times 10^{-9}$',
                                              r'$-3.5\times 10^{-6}$', 
                                              r'$1.4\times 10^{-6}$', 
                                              '0.0036', '0.0015', 
                                              '-1.09', '0.52'], 



}



Eff3 = {

        " Eu-152 Run 1 Efficiencies": ['1.000', '0.001', '0.530', 
                                       '0.012', '0.358', '0.008', 
                                       '0.211', '0.016',
                                      '0.090', '0.005',
                                      '0.088', '0.004', 
                                      '0.069', '0.004', 
                                      '0.068', '0.004', 
                                      '0.066', '0.002']


}


Eff4 = {   
    
    
    
    "Eu-152 Run 1 Intensities": ['100.0', '27.9', '97.9', '11.40', '48.0', '53.5',
                                '38.85', '49.75', '78.10', 
                                '0.12', '0.03', '1.5', '0.027', '0.09', '0.05',
                                '0.04', '0.05', '0.07'], 


}


    


df1 = pd.DataFrame(Eff1, index = [r'$a_2$', r'$\sigma{a_2}$',
                                 r'$b_2$', r'$\sigma{b_2}$', 
                                 r'$c_2$', r'$\sigma{c_2}$'])

df2 = pd.DataFrame(Eff2, index = [r'$a_3$', r'$\sigma{a_3}$',
                                 r'$b_3$', r'$\sigma{b_3}$', 
                                 r'$c_3$', r'$\sigma{c_3}$', 
                                 r'$d_3$', r'$\sigma{d_3}$'])


df3 = pd.DataFrame(Eff3, index=[
    r'$\epsilon_{\text{ff}}_1$', r'$\sigma_{\epsilon_1}$',
    r'$\epsilon_{\text{ff}}_2$', r'$\sigma_{\epsilon_2}$',
    r'$\epsilon_{\text{ff}}_3$', r'$\sigma_{\epsilon_3}$',
    r'$\epsilon_{\text{ff}}_4$', r'$\sigma_{\epsilon_4}$',
    r'$\epsilon_{\text{ff}}_5$', r'$\sigma_{\epsilon_5}$',
    r'$\epsilon_{\text{ff}}_6$', r'$\sigma_{\epsilon_6}$',
    r'$\epsilon_{\text{ff}}_7$', r'$\sigma_{\epsilon_7}$',
    r'$\epsilon_{\text{ff}}_8$', r'$\sigma_{\epsilon_8}$', 
    r'$\epsilon_{\text{ff}}_9$', r'$\sigma_{\epsilon_9}$'
])




df4 = pd.DataFrame(Eff4, index=[
     r'$I_{i_1}$', r'$\sigma_{I_1}$',
     r'$I_{i_2}$', r'$\sigma_{I_2}$',
     r'$I_{i_3}$', r'$\sigma_{I_3}$',
     r'$I_{i_4}$', r'$\sigma_{I_4}$',
     r'$I_{i_5}$', r'$\sigma_{I_5}$',
     r'$I_{i_6}$', r'$\sigma_{I_6}$', 
     r'$I_{i_7}$', r'$\sigma_{I_7}$', 
     r'$I_{i_8}$', r'$\sigma_{I_8}$', 
     r'$I_{i_9}$', r'$\sigma_{I_9}$'
])









# Export to LaTeX format
latex_table6 = df1.to_latex(escape=False)  # escape=False allows LaTeX symbols
latex_table7 = df2.to_latex(escape=False)  # escape=False allows LaTeX symbols
latex_table8 = df3.to_latex(escape=False)  # escape=False allows LaTeX symbols
latex_table9 = df4.to_latex(escape=False)  # escape=False allows LaTeX symbols

# Save to a .tex file
with open('sources.tex', 'w') as f:
    f.write(latex_table6)

# Save to a .tex file
with open('sources.tex', 'w') as f:
    f.write(latex_table7)


# Save to a .tex file
with open('sources.tex', 'w') as f:
    f.write(latex_table8)


# Save to a .tex file
with open('sources.tex', 'w') as f:
    f.write(latex_table9)







# Output the LaTeX table to the console
print(latex_table6)
print(latex_table7)
print(latex_table8)
print(latex_table9)


# Display LaTeX table
display(Latex(latex_table6))
# Display LaTeX table
display(Latex(latex_table7))
# Display LaTeX table
display(Latex(latex_table8))
# Display LaTeX table
display(Latex(latex_table9))
# Out:
# \begin{tabular}{ll}
# \toprule
#  & Low Energy Parameters (0-500 kev) \\
# \midrule
# $a_2$ & $1.28\times 10^{-6}$ \\
# $\sigma{a_2}$ & $1.27\times 10^{-6}$ \\
# $b_2$ & -0.0025 \\
# $\sigma{b_2}$ & 0.0009 \\
# $c_2$ & 1.06 \\
# $\sigma{c_2}$ & 0.14 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{ll}
# \toprule
#  & High Energy Parameters (750-1500 kev) \\
# \midrule
# $a_3$ & $1.09\times 10^{-9}$ \\
# $\sigma{a_3}$ & $.43\times 10^{-9}$ \\
# $b_3$ & $-3.5\times 10^{-6}$ \\
# $\sigma{b_3}$ & $1.4\times 10^{-6}$ \\
# $c_3$ & 0.0036 \\
# $\sigma{c_3}$ & 0.0015 \\
# $d_3$ & -1.09 \\
# $\sigma{d_3}$ & 0.52 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{ll}
# \toprule
#  &  Eu-152 Run 1 Efficiencies \\
# \midrule
# $\epsilon_{\text{ff}}_1$ & 1.000 \\
# $\sigma_{\epsilon_1}$ & 0.001 \\
# $\epsilon_{\text{ff}}_2$ & 0.530 \\
# $\sigma_{\epsilon_2}$ & 0.012 \\
# $\epsilon_{\text{ff}}_3$ & 0.358 \\
# $\sigma_{\epsilon_3}$ & 0.008 \\
# $\epsilon_{\text{ff}}_4$ & 0.211 \\
# ...
